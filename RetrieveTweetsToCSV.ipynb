# %%
# !pip install tweepy
# Out:
# ...
#     100% |████████████████████████████████| 153kB 23.1MB/s a 0:00:01
# ...
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tweepy

# %%
import csv

# %%
#Twitter API credentials
consumer_key = "4ihrxvf1Sbuaufe7RWNNGBQ4c"
consumer_secret = "wyzB7mZvxzlFOUFakETiV5USLStSX0zEaQP4qinU4QUnOjWeZi"
access_key = "2306144275-Oc7NnFdC7H9v5BjAysBz7si4OWZ9N7xmIc6XbLl"
access_secret = "UFLgsZzTYptlDTQUjjLfhG4tZzVvPkgYDVuMPitYOAVFA"

# %%
#authorize twitter, initialize tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
#initialize a list to hold all the tweepy Tweets
alltweets = []

# %%
#make initial request for most recent tweets (200 is the maximum allowed count)
new_tweets = api.user_timeline(screen_name = "boonecohealth",count=200)

# %%
#save most recent tweets
alltweets.extend(new_tweets)

# %%
len(alltweets)
# Out:
# 200

# %%
outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]

# %%
len(outtweets)
# Out:
# 200

# %%
#write the csv
with open('BooneCounty_tweets.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(["id","created_at","text"])
    writer.writerows(outtweets)

# %%
alltweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f463e51b7f0>, _json={'created_at': 'Fri Nov 01 15:32:09 +0000 2019', 'id': 1190290435627012098, 'id_str': '1190290435627012098', 'text': 'Wawona Frozen Food Voluntarily Recalls Frozen Raspberries Due to Possible Health Risk  https://t.co/lZdPBrTuUg', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/lZdPBrTuUg', 'expanded_url': 'https://www.fda.gov/safety/recalls-market-withdrawals-safety-alerts/wawona-frozen-food-voluntarily-recalls-frozen-raspberries-due-possible-health-risk', 'display_url': 'fda.gov/safety/recalls…', 'indices': [87, 110]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 66794828, 'id_str': '66794828', 'name': 'Boone County Health', 'screen_name': 'boon
# ...
